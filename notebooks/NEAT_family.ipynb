# %%
from concepts import Context

# %%
print('evolutionary --> starting point of NEAT')
print('deep --> on layers instead of neurons')
print('hierarchical --> modules and blueprints')
print('soft ordering --> the network can change the order of the layers')
print('multi-task --> MTL network')
c = Context.fromstring("""
            | neuroevolution | deep | hierarchical | soft_ordering | multi-task |
NEAT        | X              |      |              |               |            |
DeepNEAT    | X              | X    |              |               |            |
CoDeepNEAT  | X              | X    | X            |               |            |
CM          | X              | X    |              | X             |            |
CTR         | X              | X    |              | X             | X          |
CMSR        | X              | X    | X            | X             |            |
CMTR        | X              | X    | X            | X             | X          |
""")
c.lattice.graphviz()
# Out:
# evolutionary --> starting point of NEAT
# deep --> on layers instead of neurons
# hierarchical --> modules and blueprints
# soft ordering --> the network can change the order of the layers
# multi-task --> MTL network
