# %%
import utils

FRAMENET_LOCATION = '../data/framenet/subset/source'
FRAMENET_FULL_LOCATION = '../data/framenet/modern/source'
HURIC_LOCATION = '../data/huric_eb/modern/source'
FATE_LOCATION = '../data/fate/modern/source'

FOLDER_3_FRAMENET_R='../nlunetwork/results/framenet/results/eval_loss_both_slottype_full_we_large_recurrent_cell_lstm_attention_both_three_stages_true_highway___hyper:LABEL_EMB_SIZE=64,LSTM_SIZE=128,BATCH_SIZE=2,MAX_EPOCHS=100/framenet/subset_right'
FOLDER_3_FRAMENET_B='../nlunetwork/results/framenet/results/eval_loss_both_slottype_full_we_large_recurrent_cell_lstm_attention_both_three_stages_true_highway___hyper:LABEL_EMB_SIZE=64,LSTM_SIZE=128,BATCH_SIZE=2,MAX_EPOCHS=100/framenet/subset_both'

# %%
stats = utils.get_corpus_complexity_statistics(FRAMENET_LOCATION)
for stat_name, stat in stats.items():
    print(stat_name, sorted(stat.items()))

stats_fn_full = utils.get_corpus_complexity_statistics(FRAMENET_FULL_LOCATION)
stats_huric = utils.get_corpus_complexity_statistics(HURIC_LOCATION)
stats_fate = utils.get_corpus_complexity_statistics(FATE_LOCATION)
utils.plot_measures({'framenet_subset': stats, 'framenet_full': stats_fn_full, 'HuRIC': stats_huric, 'FATE': stats_fate})
# Out:
# lu_pos [('ADJ', 6), ('NOUN', 175), ('VERB', 544)]
# lu_are_roots [('False', 549), ('True', 176)]
# lengths [(1, 1), (3, 1), (4, 1), (5, 1), (6, 2), (7, 6), (8, 10), (9, 17), (10, 12), (11, 10), (12, 14), (13, 16), (14, 18), (15, 16), (16, 18), (17, 8), (18, 21), (19, 19), (20, 15), (21, 23), (22, 18), (23, 19), (24, 29), (25, 19), (26, 17), (27, 27), (28, 12), (29, 6), (30, 17), (31, 15), (32, 19), (33, 23), (34, 12), (35, 15), (36, 13), (37, 9), (38, 11), (39, 7), (40, 9), (41, 11), (42, 8), (43, 11), (44, 4), (45, 5), (46, 7), (47, 6), (48, 5), (49, 4), (50, 2), (51, 2), (52, 3), (53, 4), (54, 3), (55, 4), (57, 1), (58, 4), (59, 1), (60, 2), (61, 1), (63, 1), (67, 1), (68, 1), (69, 1), (72, 2), (73, 1), (76, 1), (79, 1), (82, 1), (83, 1), (93, 1), (153, 1)]
# lu_depths [(0, 176), (1, 185), (2, 137), (3, 94), (4, 49), (5, 35), (6, 20), (7, 15), (8, 7), (9, 2), (10, 2), (12, 2), (16, 1)]
# ...

# %%
# evaluate the framenet subdataset by the trimming strategy 'right'
samples = utils.load_json(FOLDER_3_FRAMENET_R, 99)
print('lexical_unit score:', utils.ad_align_accuracy_argmax(samples))
utils.align_score(samples, 100)
utils.display_all(samples, False, False, False, 100)
# Out:
# lexical_unit score: 0.7669172932330827
# true: Entering pred: Giving
# ...

# %%
# evaluate the framenet subdataset by the trimming strategy 'both'
# TODO rerun this training/testing because the lexical_unit_ids are not computed correctly
samples = utils.load_json(FOLDER_3_FRAMENET_B, 99)
print('lexical_unit score:', utils.ad_align_accuracy_argmax(samples))
utils.align_score(samples, 100)
utils.display_all(samples, False, False, False, 100)
# Out:
# lexical_unit score: 0.23741007194244604
# true: Motion pred: Motion
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-069c33a1bd94> in <module>()
#       4 print('lexical_unit score:', utils.ad_align_accuracy_argmax(samples))
#       5 utils.align_score(samples, 100)
# ----> 6 utils.display_all(samples, False, False, False, 100)
#
# ~/kmi/huric_rnn/notebooks/utils.py in display_all(samples, display_bd, display_ac, display_slots, max_show)
#      78     for idx, sample in enumerate(samples):
#      79         print('true:', sample['intent_true'], 'pred:', sample['intent_pred'])
# ---> 80         attentions_true, attentions_pred = get_intent_attention_arrays(sample)
#      81         display_sequences(['words', 'lexical_unit','attention_intent', 'slots_true', 'slots_pred'],
# ...
